# %% [markdown]
# # Validator Rewards

# %%
import setup
# Out:
# time: 14.1 ms (started: 2021-04-16 07:16:29 +02:00)

# %%
import pandas as pd
# Out:
# time: 462 ms (started: 2021-04-16 07:16:29 +02:00)

# %%
from experiments.run import run
from experiments.post_processing import post_process
from experiments.default import experiment
import visualizations as visualizations
# Out:
# time: 672 ms (started: 2021-04-16 07:16:29 +02:00)

# %%
results, exceptions = run(experiment)
# Out:
# Running experiment
# Experiment complete
# time: 5.71 s (started: 2021-04-16 07:16:30 +02:00)

# %%
df = pd.DataFrame(results)
df = post_process(df)
df
# Out:
#        eth_price    eth_supply    eth_staked  supply_inflation  \
# 1    1000.000000  1.120000e+08  5.242880e+05     -3.668750e-07
# 2    1022.454239  1.120001e+08  5.651227e+05      1.021577e-03
# 3    1035.122989  1.120003e+08  6.059574e+05      1.060487e-03
# 4    1051.375395  1.120004e+08  6.467921e+05      1.097914e-03
# 5    1055.165376  1.120006e+08  6.876269e+05      1.134550e-03
# ..           ...           ...           ...               ...
# 806  1073.370090  1.125943e+08  3.339623e+07      8.097913e-03
# 807  1079.194217  1.125954e+08  3.343707e+07      8.107756e-03
# 808  1080.671496  1.125965e+08  3.347790e+07      8.094385e-03
# 809  1059.174534  1.125976e+08  3.351874e+07      8.104208e-03
# 810  1034.499728  1.125987e+08  3.355957e+07      7.860449e-03
#
#      average_effective_balance  number_of_validators  \
# 1                 3.200000e+10                 16384
# 2                 3.200000e+10                 17660
# 3                 3.200000e+10                 18936
# 4                 3.200000e+10                 20212
# 5                 3.200000e+10                 21488
# ..                         ...                   ...
# 806               3.200000e+10               1043632
# 807               3.200000e+10               1044908
# 808               3.199998e+10               1046185
# 809               3.199999e+10               1047461
# 810               3.199999e+10               1048737
#
#      number_of_validators_online  number_of_validators_offline  base_reward  \
# 1                          16057                           327    8944000.0
# 2                          17307                           353    8614400.0
# 3                          18558                           378    8316800.0
# 4                          19809                           403    8051200.0
# 5                          21059                           429    7808000.0
# ..                           ...                           ...          ...
# 806                      1022798                         20834    1120000.0
# 807                      1024048                         20860    1116800.0
# 808                      1025300                         20885    1116800.0
# 809                      1026551                         20910    1081900.0
# 810                      1027801                         20936    1081900.0
#
#      validating_rewards  ...  diy_hardware_profit_yields  \
# 1          1.414641e+11  ...                    0.214715
# 2          1.468543e+11  ...                    0.206732
# 3          1.520324e+11  ...                    0.199526
# 4          1.571013e+11  ...                    0.193108
# 5          1.619666e+11  ...                    0.187171
# ..                  ...  ...                         ...
# 806        1.128383e+12  ...                    0.023987
# 807        1.126533e+12  ...                    0.023927
# 808        1.127911e+12  ...                    0.023931
# 809        1.093997e+12  ...                    0.023012
# 810        1.095329e+12  ...                    0.022931
#
#      diy_cloud_profit_yields  pool_staas_profit_yields  \
# 1                   0.217617                  0.192113
# 2                   0.209571                  0.185019
# 3                   0.202329                  0.178639
# 4                   0.195868                  0.172945
# 5                   0.189921                  0.167709
# ..                       ...                       ...
# 806                 0.026690                  0.024056
# 807                 0.026616                  0.023987
# 808                 0.026617                  0.023987
# 809                 0.025752                  0.023238
# 810                 0.025736                  0.023238
#
#      pool_hardware_profit_yields  pool_cloud_profit_yields  \
# 1                       0.216513                  0.214818
# 2                       0.208491                  0.206833
# 3                       0.201262                  0.199625
# 4                       0.194818                  0.193206
# 5                       0.188875                  0.187268
# ..                           ...                       ...
# 806                     0.025661                  0.024082
# 807                     0.025592                  0.024022
# 808                     0.025595                  0.024026
# 809                     0.024709                  0.023109
# 810                     0.024669                  0.023030
#
#      staas_full_profit_yields  staas_self_custodied_profit_yields  \
# 1                    0.185564                            0.192113
# 2                    0.178711                            0.185019
# 3                    0.172549                            0.178639
# 4                    0.167049                            0.172945
# 5                    0.161992                            0.167709
# ..                        ...                                 ...
# 806                  0.023236                            0.024056
# 807                  0.023169                            0.023987
# 808                  0.023169                            0.023987
# 809                  0.022445                            0.023238
# 810                  0.022445                            0.023238
#
#      supply_inflation_pct  total_revenue_yields_pct  total_profit_yields_pct
# 1               -0.000037                 21.831070                20.494175
# 2                0.102158                 21.024777                19.734893
# 3                0.106049                 20.299732                19.050893
# 4                0.109791                 19.652546                18.441015
# 5                0.113455                 19.057537                17.878677
# ..                    ...                       ...                      ...
# 806              0.809791                  2.733625                 2.438794
# 807              0.810776                  2.725811                 2.432197
# 808              0.809438                  2.725817                 2.432402
# 809              0.810421                  2.640639                 2.348855
# 810              0.786045                  2.640635                 2.345294
#
# [810 rows x 79 columns]
# time: 339 ms (started: 2021-04-16 07:16:36 +02:00)

# %%
visualizations.plot_validator_rewards(df)
# Out:
# time: 777 ms (started: 2021-04-16 07:16:36 +02:00)
